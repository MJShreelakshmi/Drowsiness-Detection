# %%
#Prepare a test set
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#destination path for test set
test_path = 'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\closed'

# %%
#obtaining the full path of imgs
img_list = []

for img in os.listdir(test_path):
    img_path = os.path.join(test_path, img)
    img_list.append(img_path)
print(len(img_list))

img_list[:3]
# Out:
# 75
# ['C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\closed\\drowsy161.jpg',
#  'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\closed\\drowsy162.jpg',
#  'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\closed\\drowsy163.jpg']

# %%
#import facenet

from keras_facenet import FaceNet
embedder = FaceNet()

# %%
#Extracting the closed eye images 
l_img_number = 1
r_img_number = 1

left_eye=[]
right_eye = []
for img in img_list:                                         
    detection = embedder.crop(img, threshold=0.95)
    left_eye = detection[0][0]['keypoints']['left_eye']
    right_eye = detection[0][0]['keypoints']['right_eye']
    x1, y1 = left_eye
    m1, n1 = right_eye
    l_eyes = cv2.imread(img,1)[y1-50:y1+50, x1-60:x1+60]
    r_eyes = cv2.imread(img,1)[n1-50:n1+50, m1-60:m1+60]
    crop_left= cv2.imwrite('C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\close\\l_eye'+str(l_img_number)+'.jpg', l_eyes)
    crop_right= cv2.imwrite('C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\close\\r_eye'+str(r_img_number)+'.jpg', r_eyes)
    l_img_number+=1
    r_img_number+=1

# %%
#obtaininng the full path 
opened_path = 'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\Ttest\\opend'
opened_img_list = []

for img in os.listdir(opened_path):
    img_path = os.path.join(opened_path, img)
    opened_img_list.append(img_path)
print(len(opened_img_list))

opened_img_list[:3]
# Out:
# 75
# ['C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\Ttest\\opend\\alert185.jpg',
#  'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\Ttest\\opend\\alert189.jpg',
#  'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\Ttest\\opend\\alert190.jpg']

# %%
#Extracting the opened eye images   
l_img_number = 1
r_img_number = 1

left_eye=[]
right_eye = []
for img in opened_img_list:                                         
    detection = embedder.crop(img, threshold=0.95)
    left_eye = detection[0][0]['keypoints']['left_eye']
    right_eye = detection[0][0]['keypoints']['right_eye']
    x1, y1 = left_eye
    m1, n1 = right_eye
    l_eyes = cv2.imread(img,1)[y1-50:y1+50, x1-60:x1+60]
    r_eyes = cv2.imread(img,1)[n1-50:n1+50, m1-60:m1+60]
    crop_left= cv2.imwrite('C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\Ttest\\open\\l_eye'+str(l_img_number)+'.jpg', l_eyes)
    crop_right= cv2.imwrite('C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\Ttest\\open\\r_eye'+str(r_img_number)+'.jpg', r_eyes)
    l_img_number+=1
    r_img_number+=1

# %%
# Extract imgs from videos 
import cv2
import os

# %%
# read theh video from a folder
cam = cv2.VideoCapture('C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\YawDD\\YawDD dataset\\Dash\\Male\\1-MaleGlasses.avi')

try:
    # creating a folder named 1-FemaleNoGlasses-imgs
    if not os.path.exists('C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\YawDD\\YawDD dataset\\1-MaleGlasses-imgs'):
        os.makedirs('C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\YawDD\\YawDD dataset\\1-MaleGlasses-imgs')
    
# if not created the raise error
except OSError:
    print('Error creating directory of 1-MaleGlasses-imgs')
    
# frame
currentframe=0

while (True):
    #reading from frame
    ret, frame = cam.read()
    
    if ret:
#         print(frame)
        # if video is still left continue creating imgs
        name = './frame'+str(currentframe)+'.jpg'
        print('creating ... '+name)
        
        # writing the extracted imgs
        cv2.imwrite('C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\YawDD\\YawDD dataset\\1-MaleGlasses-imgs'+name, frame)
        
        # increasing counter so that will show how many frames are created
        currentframe+=1
        print(currentframe)
    else:
        break
        
        
# release all space and windows once done
# cv2.imshow('img',img)
# cv2.waitKey(0)
# cam.release()
# cv2.destroyAllWindows()
# Out:
# creating ... ./frame0.jpg
# 1
# creating ... ./frame1.jpg
# 2
# creating ... ./frame2.jpg
# 3
# creating ... ./frame3.jpg
# 4
# creating ... ./frame4.jpg
# 5
# creating ... ./frame5.jpg
# 6
# creating ... ./frame6.jpg
# 7
# creating ... ./frame7.jpg
# 8
# creating ... ./frame8.jpg
# 9
# creating ... ./frame9.jpg
# 10
# creating ... ./frame10.jpg
# 11
# creating ... ./frame11.jpg
# 12
# creating ... ./frame12.jpg
# 13
# creating ... ./frame13.jpg
# 14
# creating ... ./frame14.jpg
# 15
# creating ... ./frame15.jpg
# 16
# creating ... ./frame16.jpg
# 17
# creating ... ./frame17.jpg
# 18
# creating ... ./frame18.jpg
# 19
# creating ... ./frame19.jpg
# 20
# creating ... ./frame20.jpg
# 21
# creating ... ./frame21.jpg
# 22
# creating ... ./frame22.jpg
# 23
# creating ... ./frame23.jpg
# 24
# creating ... ./frame24.jpg
# 25
# creating ... ./frame25.jpg
# 26
# creating ... ./frame26.jpg
# 27
# creating ... ./frame27.jpg
# 28
# creating ... ./frame28.jpg
# 29
# creating ... ./frame29.jpg
# ...

# %%
# Extracting the mouth region for yawn

# %%
#obtaining the full path 
yawnd_path = 'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\yawnd\\folder1'
yawnd_img_list = []

for img in os.listdir(yawnd_path):
    img_path = os.path.join(yawnd_path, img)
    yawnd_img_list.append(img_path)
print(len(yawnd_img_list))

yawnd_img_list[:3]
# Out:
# 25
# ['C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\yawnd\\folder1\\frame2392.jpg',
#  'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\yawnd\\folder1\\frame2395.jpg',
#  'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\yawnd\\folder1\\frame2396.jpg']

# %%
#Extracting the opened mouth images   
img_number = 1


left_lip=[]
right_lip = []
for img in yawnd_img_list:                                         
    detection = embedder.crop(img, threshold=0.95)
    x1, y1 = detection[0][0]['keypoints']['mouth_left']
    x2, y2 = detection[0][0]['keypoints']['mouth_right']

    mouth = cv2.imread(img)[y1-10:y2+30, x1-20:x2+20]
    crop_mouth= cv2.imwrite('C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\yawn\\mouth'+str(img_number)+'.jpg', mouth)
    img_number+=1

# %%
#obtaining the full path -2
yawnd_path = 'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\yawnd\\folder2'
yawnd_img_list = []

for img in os.listdir(yawnd_path):
    img_path = os.path.join(yawnd_path, img)
    yawnd_img_list.append(img_path)
print(len(yawnd_img_list))

yawnd_img_list[:3]
# Out:
# 25
# ['C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\yawnd\\folder2\\frame757.jpg',
#  'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\yawnd\\folder2\\frame758.jpg',
#  'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\yawnd\\folder2\\frame759.jpg']

# %%
#Extracting the opened mouth images   
img_number = 26


left_lip=[]
right_lip = []
for img in yawnd_img_list:                                         
    detection = embedder.crop(img, threshold=0.95)
    x1, y1 = detection[0][0]['keypoints']['mouth_left']
    x2, y2 = detection[0][0]['keypoints']['mouth_right']

    mouth = cv2.imread(img)[y1-35:y2+45, x1-20:x2+15]
    crop_mouth= cv2.imwrite('C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\yawn\\mouth'+str(img_number)+'.jpg', mouth)
    img_number+=1

# %%
# Extracting mouth for images without yawning

# %%
#obtaining the full path 
not_yawnd_path = 'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\not yawnd\\folder1'
not_yawnd_img_list = []

for img in os.listdir(not_yawnd_path):
    img_path = os.path.join(not_yawnd_path, img)
    not_yawnd_img_list.append(img_path)
print(len(not_yawnd_img_list))

not_yawnd_img_list[:3]
# Out:
# 25
# ['C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\not yawnd\\folder1\\frame0.jpg',
#  'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\not yawnd\\folder1\\frame1.jpg',
#  'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\not yawnd\\folder1\\frame10.jpg']

# %%
#Extracting the closed mouth images   
img_number = 1


left_lip=[]
right_lip = []
for img in not_yawnd_img_list:                                         
    detection = embedder.crop(img, threshold=0.95)
    x1, y1 = detection[0][0]['keypoints']['mouth_left']
    x2, y2 = detection[0][0]['keypoints']['mouth_right']

    mouth = cv2.imread(img)[y1-10:y2+30, x1-20:x2+20]
    crop_mouth= cv2.imwrite('C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\no yawn\\mouth'+str(img_number)+'.jpg', mouth)
    img_number+=1

# %%
#obtaining the full path 
not_yawnd_path = 'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\not yawnd\\folder2'
not_yawnd_img_list = []

for img in os.listdir(not_yawnd_path):
    img_path = os.path.join(not_yawnd_path, img)
    not_yawnd_img_list.append(img_path)
print(len(not_yawnd_img_list))

not_yawnd_img_list[:3]
# Out:
# 25
# ['C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\not yawnd\\folder2\\frame2605.jpg',
#  'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\not yawnd\\folder2\\frame2606.jpg',
#  'C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\not yawnd\\folder2\\frame2607.jpg']

# %%
#Extracting the opened mouth images   
img_number = 26


left_lip=[]
right_lip = []
for img in not_yawnd_img_list:                                         
    detection = embedder.crop(img, threshold=0.95)
    x1, y1 = detection[0][0]['keypoints']['mouth_left']
    x2, y2 = detection[0][0]['keypoints']['mouth_right']

    mouth = cv2.imread(img)[y1-15:y2+30, x1:x2+20]
    crop_mouth= cv2.imwrite('C:\\Users\\hp\\Documents\\Data Science\\SEM 3\\Major Project\\Datasets\\DD Data\\data-flair\\test\\no yawn\\mouth'+str(img_number)+'.jpg', mouth)
    img_number+=1

# %%
# Extracting the eyes

# %%
# display the original image
image = cv2.imread(img_list[0])
print(image.shape)
plt.imshow(image)
plt.show
# Out:
# (1080, 1920, 3)
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Draw a rectangle uisng cv2.rectangle() method    # not used ahead

# Window name in which image is displayed
window_name = 'Image'

# Start coordinate, here (5, 5)
# represents the top left corner of rectangle
start_point = (900, 550)

# Ending coordinate, here (220, 220)
# represents the bottom right corner of rectangle
end_point = (1000, 620)

# Blue color in BGR
color = (255, 0, 0)

# Line thickness of 2 px
thickness = 2

# Using cv2.rectangle() method
# Draw a rectangle with blue line borders of thickness of 2 px
e_image = cv2.rectangle(image, start_point, end_point, color, thickness)   # is an inplace function; doesnt need another variable 
                                                                            # to store the result
# Displaying the image
plt.imshow( image)
plt.show()

plt.imshow(e_image)
plt.show()

# %%
# # extract the eyes from a single image 
x1, y1 = 952,589        
width, height = 500,100

print('x1: ', x1, 'y1: ', y1, 'x2: ', x2, 'y2: ',y2)

# extract the face
eyes = image[y1-50:y1+50, x1-60:x1+60] #550:620, 900:1000
plt.imshow(eyes)
plt.show()
# Out:
# x1:  952 y1:  589 x2:  1352 y2:  689

# %%
x1, y1 = detection[0][0]['keypoints']['mouth_left']
x2, y2 = detection[0][0]['keypoints']['mouth_right']

# %%
image = cv2.imread(yawnd_img_list[80])
mouth = image[y1-35:y2+45, x1-20:x2+15] #550:620, 900:1000
plt.imshow(mouth)
plt.show()

# %%
image = cv2.imread(img_list[0])
image.shape
# Out:
# (1080, 1920, 3)

# %%
plt.imshow(cv2.imread(not_yawnd_img_list[0])[y1-15:y2+30, x1:x2+20])
